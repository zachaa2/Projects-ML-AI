# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importing the Dataset
#
# We will be using the same problem as in homework 1, which is the binary classification problem about predicting patients with breast cancer.
#
# First load the dataset

# %%
data = datasets.load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
# add target label
df['target'] = data.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Task 1 - Implement Decision Tree Classifier
#
# This time I will be using a Decision Tree Classifier to solve the binary classification problem.
#
# I will use the scikit learn package for the Decision Tree

# %% [markdown]
# ### Importing sklearn package

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %% [markdown]
# ### Split the data and fit the model to the data

# %%
# feature data
X_data = data.data
X_columns = data.feature_names
x = pd.DataFrame(X_data, columns=X_columns)

# target data
y_data = data.target
y = pd.Series(y_data, name='target')

# split into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# Decision Tree Object
clf = tree.DecisionTreeClassifier()

# fit model to data
clf = clf.fit(x_train, y_train)

# %% [markdown]
# ### Plotting the Decision Tree

# %%
# plot tree
plt.figure(figsize=(12,12))  # set plot size (denoted in inches)
tree.plot_tree(clf, fontsize=10)
# Out:
# [Text(0.6907894736842105, 0.9285714285714286, 'X[22] <= 105.95\ngini = 0.465\nsamples = 455\nvalue = [167, 288]'),
#  Text(0.4868421052631579, 0.7857142857142857, 'X[27] <= 0.158\ngini = 0.088\nsamples = 282\nvalue = [13, 269]'),
#  Text(0.34210526315789475, 0.6428571428571429, 'X[27] <= 0.135\ngini = 0.043\nsamples = 273\nvalue = [6, 267]'),
#  Text(0.21052631578947367, 0.5, 'X[13] <= 46.315\ngini = 0.015\nsamples = 260\nvalue = [2, 258]'),
#  Text(0.10526315789473684, 0.35714285714285715, 'X[21] <= 33.27\ngini = 0.008\nsamples = 257\nvalue = [1, 256]'),
#  Text(0.05263157894736842, 0.21428571428571427, 'gini = 0.0\nsamples = 239\nvalue = [0, 239]'),
#  Text(0.15789473684210525, 0.21428571428571427, 'X[21] <= 33.56\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.10526315789473684, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21052631578947367, 0.07142857142857142, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.3157894736842105, 0.35714285714285715, 'X[3] <= 469.25\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2631578947368421, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3684210526315789, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.47368421052631576, 0.5, 'X[1] <= 20.785\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.42105263157894735, 0.35714285714285715, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.5263157894736842, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.631578947368421, 0.6428571428571429, 'X[21] <= 23.47\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.5789473684210527, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6842105263157895, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8947368421052632, 0.7857142857142857, 'X[22] <= 116.05\ngini = 0.196\nsamples = 173\nvalue = [154, 19]'),
#  Text(0.8421052631578947, 0.6428571428571429, 'X[21] <= 20.355\ngini = 0.493\nsamples = 43\nvalue = [24, 19]'),
#  Text(0.7894736842105263, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.8947368421052632, 0.5, 'X[4] <= 0.09\ngini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(0.8421052631578947, 0.35714285714285715, 'X[29] <= 0.069\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.7894736842105263, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8947368421052632, 0.21428571428571427, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.9473684210526315, 0.35714285714285715, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.9473684210526315, 0.6428571428571429, 'gini = 0.0\nsamples = 130\nvalue = [130, 0]')]

# %% [markdown]
# Using the model to predict the target labels

# %%
y_pred = clf.predict(x_test)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.9122807017543859

# %% [markdown]
# ### Changing model parameters
#
# What happens when I change model parameters? First let's try and set the max_depth parameters of the model to some defined value. By default it is None, which means that the tree will be expanded until all leaves are pure.
#
# First try the Decision Tree Classifier with max depth of 3.

# %%
# new Decision Tree Object
clf = tree.DecisionTreeClassifier(max_depth=3)

# fit model to data
clf = clf.fit(x_train, y_train)

# %% [markdown]
# Plotting the new tree

# %%
# plot tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(clf, fontsize=10)
# Out:
# [Text(0.5769230769230769, 0.875, 'X[22] <= 105.95\ngini = 0.465\nsamples = 455\nvalue = [167, 288]'),
#  Text(0.3076923076923077, 0.625, 'X[27] <= 0.158\ngini = 0.088\nsamples = 282\nvalue = [13, 269]'),
#  Text(0.15384615384615385, 0.375, 'X[27] <= 0.135\ngini = 0.043\nsamples = 273\nvalue = [6, 267]'),
#  Text(0.07692307692307693, 0.125, 'gini = 0.015\nsamples = 260\nvalue = [2, 258]'),
#  Text(0.23076923076923078, 0.125, 'gini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.46153846153846156, 0.375, 'X[21] <= 23.47\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.38461538461538464, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5384615384615384, 0.125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8461538461538461, 0.625, 'X[22] <= 116.05\ngini = 0.196\nsamples = 173\nvalue = [154, 19]'),
#  Text(0.7692307692307693, 0.375, 'X[21] <= 20.355\ngini = 0.493\nsamples = 43\nvalue = [24, 19]'),
#  Text(0.6923076923076923, 0.125, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.8461538461538461, 0.125, 'gini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(0.9230769230769231, 0.375, 'gini = 0.0\nsamples = 130\nvalue = [130, 0]')]

# %% [markdown]
# As displayed above, now the graph has three levels of depth below the root node.
#
# Predicting target labels with max depth of 3

# %%
y_pred = clf.predict(x_test)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.9122807017543859

# %% [markdown]
# Clearly there is little to no difference between the defaut decision tree and this one (which is smaller). When looking at the leaves of the tree, a majority of the nodes have a gini index of 0, or close to it.
#
# Let's try making the decision tree even smaller and seeing how that affects the results.

# %%
# new Decision Tree Object
clf = tree.DecisionTreeClassifier(max_depth=1)

# fit model to data
clf = clf.fit(x_train, y_train)

# %% [markdown]
# Plotting the Tree

# %%
# plot tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(clf, fontsize=10)
# Out:
# [Text(0.5, 0.75, 'X[22] <= 105.95\ngini = 0.465\nsamples = 455\nvalue = [167, 288]'),
#  Text(0.25, 0.25, 'gini = 0.088\nsamples = 282\nvalue = [13, 269]'),
#  Text(0.75, 0.25, 'gini = 0.196\nsamples = 173\nvalue = [154, 19]')]

# %% [markdown]
# Now the tree is a graph with just one level of depth below the root node.
#
# Predicting target labels with max depth of 1

# %%
y_pred = clf.predict(x_test)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.8771929824561403

# %% [markdown]
# There is certainly a drop in the accuracy score when decreasing the maximum depth of the tree. The reason the decrease in accuracy is not too much could be due to the relatively low number of data points, or that there is not a ton of attributes

# %% [markdown]
# # Task 2 - Bagging and Boosting
#
# Now I will use ensemble techniques to solve the binary classification problem. These ensemble methods involve using more than one decision tree. There are multiple ensemble techniques to use. I will use the Bagging method, then the Boosting method.
#
# To implement the Bagging and Boosting methods, I will use the sklearn.ensemble python package.
#
# First: Implementing the **Bagging Ensemble** method

# %%
from sklearn.ensemble import BaggingClassifier

bcf = BaggingClassifier(n_estimators=3).fit(x_train, y_train)

# %% [markdown]
# Since this is an ensemble method, multiple estimators (decision trees) are used. We can plot each decision tree individually.
#
# **Estimator #1:**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(bcf.estimators_[0], fontsize=10)
# Out:
# [Text(0.640625, 0.9166666666666666, 'X[27] <= 0.136\ngini = 0.449\nsamples = 295\nvalue = [155, 300]'),
#  Text(0.40625, 0.75, 'X[23] <= 869.25\ngini = 0.077\nsamples = 193\nvalue = [12, 287]'),
#  Text(0.25, 0.5833333333333334, 'X[10] <= 0.596\ngini = 0.014\nsamples = 183\nvalue = [2, 283]'),
#  Text(0.125, 0.4166666666666667, 'X[21] <= 33.27\ngini = 0.007\nsamples = 179\nvalue = [1, 280]'),
#  Text(0.0625, 0.25, 'gini = 0.0\nsamples = 163\nvalue = [0, 250]'),
#  Text(0.1875, 0.25, 'X[21] <= 33.56\ngini = 0.062\nsamples = 16\nvalue = [1, 30]'),
#  Text(0.125, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25, 0.08333333333333333, 'gini = 0.0\nsamples = 15\nvalue = [0, 30]'),
#  Text(0.375, 0.4166666666666667, 'X[12] <= 4.249\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3125, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4375, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5625, 0.5833333333333334, 'X[21] <= 22.655\ngini = 0.408\nsamples = 10\nvalue = [10, 4]'),
#  Text(0.5, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(0.625, 0.4166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [10, 0]'),
#  Text(0.875, 0.75, 'X[13] <= 21.925\ngini = 0.153\nsamples = 102\nvalue = [143, 13]'),
#  Text(0.8125, 0.5833333333333334, 'X[1] <= 20.52\ngini = 0.455\nsamples = 13\nvalue = [7, 13]'),
#  Text(0.75, 0.4166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [0, 13]'),
#  Text(0.875, 0.4166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [7, 0]'),
#  Text(0.9375, 0.5833333333333334, 'gini = 0.0\nsamples = 89\nvalue = [136, 0]')]

# %% [markdown]
# **Estimator #2:**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(bcf.estimators_[1], fontsize=10)
# Out:
# [Text(0.631578947368421, 0.9166666666666666, 'X[22] <= 105.95\ngini = 0.48\nsamples = 278\nvalue = [182, 273]'),
#  Text(0.42105263157894735, 0.75, 'X[24] <= 0.177\ngini = 0.103\nsamples = 167\nvalue = [15, 261]'),
#  Text(0.2631578947368421, 0.5833333333333334, 'X[21] <= 33.105\ngini = 0.03\nsamples = 159\nvalue = [4, 258]'),
#  Text(0.10526315789473684, 0.4166666666666667, 'X[13] <= 46.315\ngini = 0.008\nsamples = 144\nvalue = [1, 238]'),
#  Text(0.05263157894736842, 0.25, 'gini = 0.0\nsamples = 142\nvalue = [0, 235]'),
#  Text(0.15789473684210525, 0.25, 'X[28] <= 0.212\ngini = 0.375\nsamples = 2\nvalue = [1, 3]'),
#  Text(0.10526315789473684, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21052631578947367, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]'),
#  Text(0.42105263157894735, 0.4166666666666667, 'X[21] <= 34.73\ngini = 0.227\nsamples = 15\nvalue = [3, 20]'),
#  Text(0.3684210526315789, 0.25, 'X[12] <= 2.757\ngini = 0.375\nsamples = 3\nvalue = [3, 1]'),
#  Text(0.3157894736842105, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(0.42105263157894735, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.47368421052631576, 0.25, 'gini = 0.0\nsamples = 12\nvalue = [0, 19]'),
#  Text(0.5789473684210527, 0.5833333333333334, 'X[27] <= 0.142\ngini = 0.337\nsamples = 8\nvalue = [11, 3]'),
#  Text(0.5263157894736842, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(0.631578947368421, 0.4166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [11, 0]'),
#  Text(0.8421052631578947, 0.75, 'X[23] <= 871.8\ngini = 0.125\nsamples = 111\nvalue = [167, 12]'),
#  Text(0.7894736842105263, 0.5833333333333334, 'X[24] <= 0.129\ngini = 0.49\nsamples = 21\nvalue = [16, 12]'),
#  Text(0.7368421052631579, 0.4166666666666667, 'gini = 0.0\nsamples = 7\nvalue = [0, 9]'),
#  Text(0.8421052631578947, 0.4166666666666667, 'X[3] <= 652.15\ngini = 0.266\nsamples = 14\nvalue = [16, 3]'),
#  Text(0.7894736842105263, 0.25, 'gini = 0.0\nsamples = 10\nvalue = [15, 0]'),
#  Text(0.8947368421052632, 0.25, 'X[27] <= 0.159\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8421052631578947, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9473684210526315, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8947368421052632, 0.5833333333333334, 'gini = 0.0\nsamples = 90\nvalue = [151, 0]')]

# %% [markdown]
# **Estimator #3:**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(bcf.estimators_[2], fontsize=10)
# Out:
# [Text(0.5277777777777778, 0.9, 'X[22] <= 107.75\ngini = 0.467\nsamples = 304\nvalue = [169, 286]'),
#  Text(0.2777777777777778, 0.7, 'X[27] <= 0.135\ngini = 0.105\nsamples = 191\nvalue = [16, 272]'),
#  Text(0.1111111111111111, 0.5, 'X[21] <= 33.105\ngini = 0.008\nsamples = 174\nvalue = [1, 261]'),
#  Text(0.05555555555555555, 0.3, 'gini = 0.0\nsamples = 166\nvalue = [0, 250]'),
#  Text(0.16666666666666666, 0.3, 'X[1] <= 23.845\ngini = 0.153\nsamples = 8\nvalue = [1, 11]'),
#  Text(0.1111111111111111, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2222222222222222, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [0, 11]'),
#  Text(0.4444444444444444, 0.5, 'X[21] <= 27.41\ngini = 0.488\nsamples = 17\nvalue = [15, 11]'),
#  Text(0.3888888888888889, 0.3, 'X[29] <= 0.122\ngini = 0.153\nsamples = 7\nvalue = [1, 11]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 11]'),
#  Text(0.4444444444444444, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.3, 'gini = 0.0\nsamples = 10\nvalue = [14, 0]'),
#  Text(0.7777777777777778, 0.7, 'X[1] <= 15.65\ngini = 0.154\nsamples = 113\nvalue = [153, 14]'),
#  Text(0.6666666666666666, 0.5, 'X[27] <= 0.145\ngini = 0.484\nsamples = 12\nvalue = [7, 10]'),
#  Text(0.6111111111111112, 0.3, 'gini = 0.0\nsamples = 7\nvalue = [0, 10]'),
#  Text(0.7222222222222222, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [7, 0]'),
#  Text(0.8888888888888888, 0.5, 'X[7] <= 0.041\ngini = 0.052\nsamples = 101\nvalue = [146, 4]'),
#  Text(0.8333333333333334, 0.3, 'X[3] <= 685.15\ngini = 0.48\nsamples = 9\nvalue = [6, 4]'),
#  Text(0.7777777777777778, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8888888888888888, 0.1, 'gini = 0.0\nsamples = 5\nvalue = [6, 0]'),
#  Text(0.9444444444444444, 0.3, 'gini = 0.0\nsamples = 92\nvalue = [140, 0]')]

# %% [markdown]
# **Measuring the Performance:** k-Fold cross validation
#
# We can use K-Fold Cross Validation to divide the data into folds, where each fold will be made of training partition and a validation partition.

# %%
# implement k-fold cross validation
from sklearn.model_selection import KFold

# %%
# use three folds
k = 3

kfold = KFold(n_splits=k)

# redefine the bagging model
bcf = BaggingClassifier(n_estimators=3)

acc = []

for train_index, test_index in kfold.split(x):
    xtrain , xtest = x.iloc[train_index,:], x.iloc[test_index,:]
    ytrain , ytest = y[train_index] , y[test_index]
    
    bcf.fit(xtrain, ytrain)
    
    pred = bcf.predict(xtest)
    
    accuracy = accuracy_score(pred, ytest)
    acc.append(accuracy)

avg_acc = sum(acc) / k

print('accuracy of each fold - {}'.format(acc))
print('Avg accuracy : {}'.format(avg_acc))
# Out:
# accuracy of each fold - [0.8842105263157894, 0.9578947368421052, 0.9365079365079365]
# Avg accuracy : 0.9262043998886105
