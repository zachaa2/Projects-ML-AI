# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importing the Dataset
#
# We will be using the same problem as in homework 1, which is the binary classification problem about predicting patients with breast cancer.
#
# First load the dataset

# %%
data = datasets.load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
# add target label
df['target'] = data.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Task 1 - Implement Decision Tree Classifier
#
# This time I will be using a Decision Tree Classifier to solve the binary classification problem.
#
# I will use the scikit learn package for the Decision Tree
#
# [Documentation](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)

# %% [markdown]
# ### Importing sklearn package

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %% [markdown]
# ### Split the data and fit the model to the data

# %%
# feature data
X_data = data.data
X_columns = data.feature_names
x = pd.DataFrame(X_data, columns=X_columns)

# target data
y_data = data.target
y = pd.Series(y_data, name='target')

# split into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# Decision Tree Object
clf = tree.DecisionTreeClassifier()

# fit model to data
clf = clf.fit(x_train, y_train)

# %% [markdown]
# ### Plotting the Decision Tree

# %%
# plot tree
plt.figure(figsize=(12,12))  # set plot size (denoted in inches)
tree.plot_tree(clf, fontsize=10)
# Out:
# [Text(0.6907894736842105, 0.9285714285714286, 'X[22] <= 105.95\ngini = 0.465\nsamples = 455\nvalue = [167, 288]'),
#  Text(0.4868421052631579, 0.7857142857142857, 'X[27] <= 0.158\ngini = 0.088\nsamples = 282\nvalue = [13, 269]'),
#  Text(0.34210526315789475, 0.6428571428571429, 'X[27] <= 0.135\ngini = 0.043\nsamples = 273\nvalue = [6, 267]'),
#  Text(0.21052631578947367, 0.5, 'X[13] <= 46.315\ngini = 0.015\nsamples = 260\nvalue = [2, 258]'),
#  Text(0.10526315789473684, 0.35714285714285715, 'X[21] <= 33.27\ngini = 0.008\nsamples = 257\nvalue = [1, 256]'),
#  Text(0.05263157894736842, 0.21428571428571427, 'gini = 0.0\nsamples = 239\nvalue = [0, 239]'),
#  Text(0.15789473684210525, 0.21428571428571427, 'X[21] <= 33.56\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.10526315789473684, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21052631578947367, 0.07142857142857142, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.3157894736842105, 0.35714285714285715, 'X[24] <= 0.107\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2631578947368421, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3684210526315789, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.47368421052631576, 0.5, 'X[21] <= 29.455\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.42105263157894735, 0.35714285714285715, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.5263157894736842, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.631578947368421, 0.6428571428571429, 'X[21] <= 23.47\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.5789473684210527, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6842105263157895, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8947368421052632, 0.7857142857142857, 'X[22] <= 116.05\ngini = 0.196\nsamples = 173\nvalue = [154, 19]'),
#  Text(0.8421052631578947, 0.6428571428571429, 'X[21] <= 20.355\ngini = 0.493\nsamples = 43\nvalue = [24, 19]'),
#  Text(0.7894736842105263, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.8947368421052632, 0.5, 'X[4] <= 0.09\ngini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(0.8421052631578947, 0.35714285714285715, 'X[3] <= 706.6\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.7894736842105263, 0.21428571428571427, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8947368421052632, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9473684210526315, 0.35714285714285715, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.9473684210526315, 0.6428571428571429, 'gini = 0.0\nsamples = 130\nvalue = [130, 0]')]

# %% [markdown]
# Using the model to predict the target labels

# %%
y_pred = clf.predict(x_test)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.9210526315789473

# %% [markdown]
# ### Changing model parameters
#
# What happens when I change model parameters? First let's try and set the max_depth parameters of the model to some defined value. By default it is None, which means that the tree will be expanded until all leaves are pure.
#
# First try the Decision Tree Classifier with max depth of 3.

# %%
# new Decision Tree Object
clf = tree.DecisionTreeClassifier(max_depth=3)

# fit model to data
clf = clf.fit(x_train, y_train)

# %% [markdown]
# Plotting the new tree

# %%
# plot tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(clf, fontsize=10)
# Out:
# [Text(0.5769230769230769, 0.875, 'X[22] <= 105.95\ngini = 0.465\nsamples = 455\nvalue = [167, 288]'),
#  Text(0.3076923076923077, 0.625, 'X[27] <= 0.158\ngini = 0.088\nsamples = 282\nvalue = [13, 269]'),
#  Text(0.15384615384615385, 0.375, 'X[27] <= 0.135\ngini = 0.043\nsamples = 273\nvalue = [6, 267]'),
#  Text(0.07692307692307693, 0.125, 'gini = 0.015\nsamples = 260\nvalue = [2, 258]'),
#  Text(0.23076923076923078, 0.125, 'gini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.46153846153846156, 0.375, 'X[21] <= 23.47\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.38461538461538464, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5384615384615384, 0.125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8461538461538461, 0.625, 'X[22] <= 116.05\ngini = 0.196\nsamples = 173\nvalue = [154, 19]'),
#  Text(0.7692307692307693, 0.375, 'X[21] <= 20.355\ngini = 0.493\nsamples = 43\nvalue = [24, 19]'),
#  Text(0.6923076923076923, 0.125, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.8461538461538461, 0.125, 'gini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(0.9230769230769231, 0.375, 'gini = 0.0\nsamples = 130\nvalue = [130, 0]')]

# %% [markdown]
# As displayed above, now the graph has three levels of depth below the root node.
#
# Predicting target labels with max depth of 3

# %%
y_pred = clf.predict(x_test)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.9122807017543859

# %% [markdown]
# Clearly there is little to no difference between the defaut decision tree and this one (which is smaller). When looking at the leaves of the tree, a majority of the nodes have a gini index of 0, or close to it.
#
# Let's try making the decision tree even smaller and seeing how that affects the results.

# %%
# new Decision Tree Object
clf = tree.DecisionTreeClassifier(max_depth=1)

# fit model to data
clf = clf.fit(x_train, y_train)

# %% [markdown]
# Plotting the Tree

# %%
# plot tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(clf, fontsize=10)
# Out:
# [Text(0.5, 0.75, 'X[22] <= 105.95\ngini = 0.465\nsamples = 455\nvalue = [167, 288]'),
#  Text(0.25, 0.25, 'gini = 0.088\nsamples = 282\nvalue = [13, 269]'),
#  Text(0.75, 0.25, 'gini = 0.196\nsamples = 173\nvalue = [154, 19]')]

# %% [markdown]
# Now the tree is a graph with just one level of depth below the root node.
#
# Predicting target labels with max depth of 1

# %%
y_pred = clf.predict(x_test)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.8771929824561403

# %% [markdown]
# There is certainly a drop in the accuracy score when decreasing the maximum depth of the tree. The reason the decrease in accuracy is not too much could be due to the relatively low number of data points, or that there is not a ton of attributes

# %% [markdown]
# **Measuring the Performance:** k-Fold cross validation
#
# We can use K-Fold Cross Validation to divide the data into folds.

# %%
# implement k-fold cross validation
from sklearn.model_selection import KFold

# %% [markdown]
# First with the default max depth value

# %%
# use three folds
k = 3

kfold = KFold(n_splits=k)

# redefine the bagging model
# new Decision Tree Object
clf = tree.DecisionTreeClassifier()

acc = []

for train_index, test_index in kfold.split(x):
    xtrain , xtest = x.iloc[train_index,:], x.iloc[test_index,:]
    ytrain , ytest = y[train_index] , y[test_index]
    
    clf.fit(xtrain, ytrain)
    
    pred = clf.predict(xtest)
    
    accuracy = accuracy_score(pred, ytest)
    acc.append(accuracy)

avg_acc = sum(acc) / k

print('accuracy of each fold - {}'.format(acc))
print('Avg accuracy : {}'.format(avg_acc))
# Out:
# accuracy of each fold - [0.9, 0.9368421052631579, 0.8677248677248677]
# Avg accuracy : 0.901522324329342

# %% [markdown]
# Next with the max_depth of 1

# %%
# use three folds
k = 3

kfold = KFold(n_splits=k)

# redefine the bagging model
# new Decision Tree Object
clf = tree.DecisionTreeClassifier(max_depth=1)

acc = []

for train_index, test_index in kfold.split(x):
    xtrain , xtest = x.iloc[train_index,:], x.iloc[test_index,:]
    ytrain , ytest = y[train_index] , y[test_index]
    
    clf.fit(xtrain, ytrain)
    
    pred = clf.predict(xtest)
    
    accuracy = accuracy_score(pred, ytest)
    acc.append(accuracy)

avg_acc = sum(acc) / k

print('accuracy of each fold - {}'.format(acc))
print('Avg accuracy : {}'.format(avg_acc))
# Out:
# accuracy of each fold - [0.8421052631578947, 0.9157894736842105, 0.8994708994708994]
# Avg accuracy : 0.8857885454376682

# %% [markdown]
# # Task 2 - Bagging and Boosting
#
# Now I will use ensemble techniques to solve the binary classification problem. These ensemble methods involve using more than one decision tree. There are multiple ensemble techniques to use. I will use the Bagging method, then the Boosting method.
#
# To implement the Bagging and Boosting methods, I will use the sklearn.ensemble python package.
#
# First: Implementing the **Bagging Ensemble** method
#
# From the sklearn webpage:
#
# A Bagging classifier is an ensemble meta-estimator that fits base classifiers each on random subsets of the original dataset and then aggregate their individual predictions (either by voting or by averaging) to form a final prediction.
#
# [Documentation](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingClassifier.html)

# %%
from sklearn.ensemble import BaggingClassifier

bcf = BaggingClassifier(n_estimators=3).fit(x_train, y_train)

# %% [markdown]
# Since this is an ensemble method, multiple estimators (decision trees) are used. We can plot each decision tree individually.
#
# **Estimator #1:**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(bcf.estimators_[0], fontsize=10)
# Out:
# [Text(0.7205882352941176, 0.9375, 'X[22] <= 114.65\ngini = 0.459\nsamples = 292\nvalue = [162, 293]'),
#  Text(0.6617647058823529, 0.8125, 'X[27] <= 0.147\ngini = 0.164\nsamples = 206\nvalue = [29, 293]'),
#  Text(0.4411764705882353, 0.6875, 'X[13] <= 42.19\ngini = 0.082\nsamples = 191\nvalue = [13, 290]'),
#  Text(0.29411764705882354, 0.5625, 'X[22] <= 108.25\ngini = 0.046\nsamples = 186\nvalue = [7, 288]'),
#  Text(0.17647058823529413, 0.4375, 'X[25] <= 0.455\ngini = 0.014\nsamples = 174\nvalue = [2, 276]'),
#  Text(0.11764705882352941, 0.3125, 'X[24] <= 0.188\ngini = 0.007\nsamples = 173\nvalue = [1, 276]'),
#  Text(0.058823529411764705, 0.1875, 'gini = 0.0\nsamples = 171\nvalue = [0, 275]'),
#  Text(0.17647058823529413, 0.1875, 'X[12] <= 1.804\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11764705882352941, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23529411764705882, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23529411764705882, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4117647058823529, 0.4375, 'X[21] <= 20.085\ngini = 0.415\nsamples = 12\nvalue = [5, 12]'),
#  Text(0.35294117647058826, 0.3125, 'gini = 0.0\nsamples = 8\nvalue = [0, 11]'),
#  Text(0.47058823529411764, 0.3125, 'X[15] <= 0.032\ngini = 0.278\nsamples = 4\nvalue = [5, 1]'),
#  Text(0.4117647058823529, 0.1875, 'gini = 0.0\nsamples = 3\nvalue = [5, 0]'),
#  Text(0.5294117647058824, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5882352941176471, 0.5625, 'X[17] <= 0.015\ngini = 0.375\nsamples = 5\nvalue = [6, 2]'),
#  Text(0.5294117647058824, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [6, 0]'),
#  Text(0.6470588235294118, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8823529411764706, 0.6875, 'X[24] <= 0.143\ngini = 0.266\nsamples = 15\nvalue = [16, 3]'),
#  Text(0.8235294117647058, 0.5625, 'X[14] <= 0.009\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7647058823529411, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8823529411764706, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9411764705882353, 0.5625, 'gini = 0.0\nsamples = 11\nvalue = [15, 0]'),
#  Text(0.7794117647058824, 0.8125, 'gini = 0.0\nsamples = 86\nvalue = [133, 0]')]

# %% [markdown]
# **Estimator #2:**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(bcf.estimators_[1], fontsize=10)
# Out:
# [Text(0.5789473684210527, 0.9285714285714286, 'X[22] <= 105.95\ngini = 0.442\nsamples = 291\nvalue = [150, 305]'),
#  Text(0.3684210526315789, 0.7857142857142857, 'X[7] <= 0.06\ngini = 0.081\nsamples = 190\nvalue = [13, 293]'),
#  Text(0.2631578947368421, 0.6428571428571429, 'X[13] <= 46.315\ngini = 0.033\nsamples = 183\nvalue = [5, 289]'),
#  Text(0.21052631578947367, 0.5, 'X[25] <= 0.437\ngini = 0.02\nsamples = 182\nvalue = [3, 289]'),
#  Text(0.10526315789473684, 0.35714285714285715, 'X[21] <= 33.105\ngini = 0.007\nsamples = 178\nvalue = [1, 287]'),
#  Text(0.05263157894736842, 0.21428571428571427, 'gini = 0.0\nsamples = 166\nvalue = [0, 266]'),
#  Text(0.15789473684210525, 0.21428571428571427, 'X[21] <= 33.56\ngini = 0.087\nsamples = 12\nvalue = [1, 21]'),
#  Text(0.10526315789473684, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21052631578947367, 0.07142857142857142, 'gini = 0.0\nsamples = 11\nvalue = [0, 21]'),
#  Text(0.3157894736842105, 0.35714285714285715, 'X[8] <= 0.19\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.2631578947368421, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3684210526315789, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3157894736842105, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.47368421052631576, 0.6428571428571429, 'X[6] <= 0.121\ngini = 0.444\nsamples = 7\nvalue = [8, 4]'),
#  Text(0.42105263157894735, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(0.5263157894736842, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [8, 0]'),
#  Text(0.7894736842105263, 0.7857142857142857, 'X[7] <= 0.032\ngini = 0.148\nsamples = 101\nvalue = [137, 12]'),
#  Text(0.6842105263157895, 0.6428571428571429, 'X[19] <= 0.002\ngini = 0.346\nsamples = 7\nvalue = [2, 7]'),
#  Text(0.631578947368421, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7368421052631579, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 7]'),
#  Text(0.8947368421052632, 0.6428571428571429, 'X[21] <= 20.355\ngini = 0.069\nsamples = 94\nvalue = [135, 5]'),
#  Text(0.8421052631578947, 0.5, 'X[26] <= 0.361\ngini = 0.469\nsamples = 6\nvalue = [3, 5]'),
#  Text(0.7894736842105263, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 5]'),
#  Text(0.8947368421052632, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9473684210526315, 0.5, 'gini = 0.0\nsamples = 88\nvalue = [132, 0]')]

# %% [markdown]
# **Estimator #3:**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(bcf.estimators_[2], fontsize=10)
# Out:
# [Text(0.6166666666666667, 0.9166666666666666, 'X[27] <= 0.136\ngini = 0.455\nsamples = 286\nvalue = [159, 296]'),
#  Text(0.43333333333333335, 0.75, 'X[20] <= 17.22\ngini = 0.1\nsamples = 189\nvalue = [16, 287]'),
#  Text(0.26666666666666666, 0.5833333333333334, 'X[13] <= 37.61\ngini = 0.034\nsamples = 181\nvalue = [5, 285]'),
#  Text(0.13333333333333333, 0.4166666666666667, 'X[21] <= 32.83\ngini = 0.021\nsamples = 177\nvalue = [3, 282]'),
#  Text(0.06666666666666667, 0.25, 'gini = 0.0\nsamples = 165\nvalue = [0, 261]'),
#  Text(0.2, 0.25, 'X[21] <= 33.56\ngini = 0.219\nsamples = 12\nvalue = [3, 21]'),
#  Text(0.13333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'),
#  Text(0.26666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 11\nvalue = [0, 21]'),
#  Text(0.4, 0.4166666666666667, 'X[21] <= 27.795\ngini = 0.48\nsamples = 4\nvalue = [2, 3]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]'),
#  Text(0.4666666666666667, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6, 0.5833333333333334, 'X[1] <= 17.12\ngini = 0.26\nsamples = 8\nvalue = [11, 2]'),
#  Text(0.5333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'gini = 0.0\nsamples = 7\nvalue = [11, 0]'),
#  Text(0.8, 0.75, 'X[13] <= 14.18\ngini = 0.111\nsamples = 97\nvalue = [143, 9]'),
#  Text(0.7333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(0.8666666666666667, 0.5833333333333334, 'X[27] <= 0.145\ngini = 0.065\nsamples = 95\nvalue = [143, 5]'),
#  Text(0.8, 0.4166666666666667, 'X[1] <= 20.12\ngini = 0.401\nsamples = 12\nvalue = [13, 5]'),
#  Text(0.7333333333333333, 0.25, 'X[27] <= 0.138\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.08333333333333333, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8666666666666667, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [12, 0]'),
#  Text(0.9333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 83\nvalue = [130, 0]')]

# %% [markdown]
# **Measuring the Performance:** k-Fold cross validation
#
# We can use K-Fold Cross Validation to divide the data into folds, where each fold will be made of training partition and a validation partition.

# %%
# use three folds
k = 3

kfold = KFold(n_splits=k)

# redefine the bagging model
bcf = BaggingClassifier(n_estimators=3)

acc = []

for train_index, test_index in kfold.split(x):
    xtrain , xtest = x.iloc[train_index,:], x.iloc[test_index,:]
    ytrain , ytest = y[train_index] , y[test_index]
    
    bcf.fit(xtrain, ytrain)
    
    pred = bcf.predict(xtest)
    
    accuracy = accuracy_score(pred, ytest)
    acc.append(accuracy)

avg_acc = sum(acc) / k

print('accuracy of each fold - {}'.format(acc))
print('Avg accuracy : {}'.format(avg_acc))
# Out:
# accuracy of each fold - [0.8894736842105263, 0.9526315789473684, 0.9365079365079365]
# Avg accuracy : 0.9262043998886105

# %% [markdown]
# There seems to be a slight improvement by using the Bagging Classifier over the traditional Decision Tree Classifier.
#
# Now let's use the other ensemble method: **Boosting Classifier**
#
# From the sklearn webpage:
#
# An AdaBoost classifier is a meta-estimator that begins by fitting a classifier on the original dataset and then fits additional copies of the classifier on the same dataset but where the weights of incorrectly classified instances are adjusted such that subsequent classifiers focus more on difficult cases.
#
# [Documentation](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html)

# %%
# implementing the Boosting Classifier using sklearn
from sklearn.ensemble import AdaBoostClassifier

cf = AdaBoostClassifier(n_estimators=3, algorithm='SAMME').fit(x_train, y_train)

# %% [markdown]
# The Boosting Method is also an ensemble method, so multiple estimators are used. We can plot each decision tree individually.
#
# **Estimator #1:**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(cf.estimators_[0], fontsize=10)
# Out:
# [Text(0.5, 0.75, 'X[22] <= 105.95\ngini = 0.465\nsamples = 455\nvalue = [0.367, 0.633]'),
#  Text(0.25, 0.25, 'gini = 0.088\nsamples = 282\nvalue = [0.029, 0.591]'),
#  Text(0.75, 0.25, 'gini = 0.196\nsamples = 173\nvalue = [0.338, 0.042]')]

# %% [markdown]
# **Estimator #2:**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(cf.estimators_[1], fontsize=10)
# Out:
# [Text(0.5, 0.75, 'X[27] <= 0.145\ngini = 0.474\nsamples = 455\nvalue = [0.385, 0.615]'),
#  Text(0.25, 0.25, 'gini = 0.262\nsamples = 313\nvalue = [0.109, 0.593]'),
#  Text(0.75, 0.25, 'gini = 0.134\nsamples = 142\nvalue = [0.276, 0.022]')]

# %% [markdown]
# **Estimator #3**

# %%
# plotting all three tree
plt.figure(figsize=(12,12))  # set plot size
tree.plot_tree(cf.estimators_[2], fontsize=10)
# Out:
# [Text(0.5, 0.75, 'X[21] <= 23.35\ngini = 0.488\nsamples = 455\nvalue = [0.576, 0.424]'),
#  Text(0.25, 0.25, 'gini = 0.122\nsamples = 177\nvalue = [0.019, 0.275]'),
#  Text(0.75, 0.25, 'gini = 0.333\nsamples = 278\nvalue = [0.557, 0.149]')]

# %% [markdown]
# **Measuring the Performance:** k-Fold cross validation
#
# Once again, we can use K-Fold Cross Validation to divide the data into folds, where each fold will be made of training partition and a validation partition.

# %%
# use three folds
k = 3

kfold = KFold(n_splits=k)

# redefine the boosting model
cf = AdaBoostClassifier(n_estimators=3, algorithm='SAMME')

acc = []

for train_index, test_index in kfold.split(x):
    xtrain , xtest = x.iloc[train_index,:], x.iloc[test_index,:]
    ytrain , ytest = y[train_index] , y[test_index]
    
    cf.fit(xtrain, ytrain)
    
    pred = bcf.predict(xtest)
    
    accuracy = accuracy_score(pred, ytest)
    acc.append(accuracy)

avg_acc = sum(acc) / k

print('accuracy of each fold - {}'.format(acc))
print('Avg accuracy : {}'.format(avg_acc))
# Out:
# accuracy of each fold - [0.9842105263157894, 0.9947368421052631, 0.9365079365079365]
# Avg accuracy : 0.9718184349763298

# %% [markdown]
# **Differences/Similarities**
#
# Based off these results, the boosting algorithm provides an even greater level of accuracy. Both ensemble methods achieve an accuracy of over 90%, and both seem to outperform the standard Decision Tree Classifier on average.
#
# It is interesting to note the different in performance between the three models. From worst to best, the models were Decision Tree Classifer, Bagging Classifier, and Ada Boost Classifier. However, the difference between the Decision Tree and Bagging Classifiers was much less than the difference between the Bagging and Boosting Classifiers.
#
# I think it is also important to note that the dataset imported from sklearn is actually relatively small, so these differences may become more or less drasting when dealing with larger or even different types of datasets.

# %% [markdown]
# # Task 3 - Comparing Effectiveness

# %% [markdown]
# To compare the **effectiveness** of the three methods, I used K-Fold cross validation. This involves splitting the entire dataset into multiple folds, where each fold is made of training sets and a validation set. K-Fold cross validation is particularly good because it works well to protect against overfitting in a predictive model. This is particularly helpful in the case where the amount of data is limited, and models become more prone to overfitting. In cases where data is limited, the model may work well on a particular train-test-split done, but we'll have a hard time finding out if it will work on **unseen data** without trial and error. Cross validation techniques are used to protect against overfitting.
#
# **For example**, if you're solving a problem and the data has only 500 entries, the model may overfit to the data, and may not work as well on data not in the data set. The overfitting problem will not be revealed easily using the normal train-test-split, beacuse the dataset will only be split once. Say a 80-20 split is used, then 400 data points will be used for the train and just 100 on the testing set. It's not easy to know how effective the model is with these partitions. K-Fold Cross Validation can help to combat this problem. By creating multiple folds, we are calculating accuracies multiple times (once per fold). Each fold is made of its own training and validation set. In general, if the model good agerave performance using k-fold cross validation, we can be more confident that the model will work on new data, compared to other metrics lice accuracy score.
#
# **The cross validation metric is suitable for the problem at hand** because it can prove as a safer and more robust way of evaluating the performance of the models. The dataset imported for this problem is relatively small, which means the model is prone to overfitting. Cross validation will evaluate the model while protectinng against that problem.

# %% [markdown]
# ### Effectiveness Ranked
#
# From lest effective to most effective:
#
# Decision Tree Classifier, Bagging Classifier, Adaptive Boosting Classifier

# %% [markdown]
# The Decision Tree had an average accuracy from around 87-93% depending on the depth of the tree
#
# The Bagging Classifier had an average accuracy of approx. 93%
#
# The Adaptive Boosting Classifier had an average accuracy of approx. 96%
#
# See task 1 and task 2 to see examples on how I implemented k-fold cross validation.

# %% [markdown]
# **Other Metrics**
#
# Another metric used to evaluate the performance of models is the confusion matrix. The Confusion Matrix shows the breakdown of TP, FP, TN, FN.
#
# TP - True Positive
# FP - False Positive
# TN - True Negative
# FN - False Negative
#
# Showing the breakdown of these metrics in a matrix can often be a useful source of information regarding the performance of the model. These metrics are specifically relevant to binary classifiaction problems, which involve Yes/No answers. In general, a model with a high accuracy will have a high number of TP and TN values, which make up the diagonal of the matrix.
#
# In this specific problem, the confusion matrix may not be the most useful method of evaluating effectiveness. As shown in my EDA section in Homework1, this dataset has a skewed number of target labels, so the numbers in the matrix may not be the most useful piece of information. Also, K-Fold cross validation serves as a better way to evaluate performance, especially for problems with small datasets as discussed above.
#
# Below is an implementation of rendering the confusion matrix, given the ground truth and predicted values.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# split into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=20)

# Decision Tree Object
clf = tree.DecisionTreeClassifier().fit(x_train, y_train)

y_pred = clf.predict(x_test)

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %% [markdown]
# As shown by the above confusion matrix, the diagonal of the matrix is filled with relatively high numbers. This means the model's accuracy is relatively high. There is certainly a clear discrepancy between the False Negative and the False Positive values, but this could be due to the fact that there are more data points labeled as 1 compared to 0.
#
# The Confusion Matrix certainly offers insightful information beyond just the accuracy score, but it still uses the typical train-test-split, which can fail to reveal problems due to overfitting as discussed above.
